# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b4bc7c62-e955-4bd9-8353-8f11609a56e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4bc7c62-e955-4bd9-8353-8f11609a56e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
housing = pd.read_csv('housing.csv')
# Out:
# 0.4999

# %%
housing.hist(bins=50, figsize=(12,8),color='red')
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# **Creating a Test Set**

# %%
def shuffle_split_data(data,test_ratio):
  np.random.seed(42) #so that same random numbers are generated everytime
  random_indices = np.random.permutation(len(data)) #generate a combination of numbers from 0 to len(data) -1
  test_size = int(len(data)*test_ratio) #create an indices limit
  test_indices = random_indices[:test_size] #take all indices from 0 to test_size -1
  training_indices = random_indices[test_size:] #take all indices from test_size to len(data)-1
  return data.iloc[test_indices],data.iloc[training_indices] #return two datasets one for training and another for testing

training_set , test_set = shuffle_split_data(housing,0.2)
print(len(training_set))
print(len(test_set))
# Out:
# 4128
# 16512
